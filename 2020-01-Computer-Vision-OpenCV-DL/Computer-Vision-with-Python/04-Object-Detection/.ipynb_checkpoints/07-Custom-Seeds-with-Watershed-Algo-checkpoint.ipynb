# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>
# *Copyright by Pierian Data Inc.*

# %% [markdown]
# # Custom Seeds with the WaterShed Algorithm
#
# Previously we did a lot of work for OpenCV to set Markers to provide seeds to the Watershed Algorithm. But what if we just provide seeds ourselves? Let's try it out!

# %% [markdown]
# ## Imports

# %%
import cv2
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read in the Image and Make a Copy

# %%
road = cv2.imread('../DATA/road_image.jpg')
road_copy = np.copy(road)

# %%
plt.imshow(road)

# %% [markdown]
# #### Create an empty space for the results to be drawn

# %%
road.shape
# Out:
# (600, 800, 3)

# %%
road.shape[:2]
# Out:
# (600, 800)

# %%
marker_image = np.zeros(road.shape[:2],dtype=np.int32)

# %%
segments = np.zeros(road.shape,dtype=np.uint8)

# %%
segments.shape
# Out:
# (600, 800, 3)

# %% [markdown]
# ### Create colors for Markers
#
# https://matplotlib.org/examples/color/colormaps_reference.html

# %%
from matplotlib import cm

# %% [markdown]
# Returns (R,G,B,Alpha) we only need RGB values

# %%
#parametros de colores
cm.tab10(0)
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0)

# %%
cm.tab10(1)
# Out:
# (1.0, 0.4980392156862745, 0.054901960784313725, 1.0)

# %%
np.array(cm.tab10(0))
# Out:
# array([0.12156863, 0.46666667, 0.70588235, 1.        ])

# %%
np.array(cm.tab10(0))[:3]
# Out:
# array([0.12156863, 0.46666667, 0.70588235])

# %%
np.array(cm.tab10(0))[:3]*255
# Out:
# array([ 31., 119., 180.])

# %%
x = np.array(cm.tab10(0))[:3]*255

# %%
x.astype(int)
# Out:
# array([ 31, 119, 180])

# %%
tuple(x.astype(int))
# Out:
# (31, 119, 180)

# %% [markdown]
# Let's make a function for all those steps

# %%
def create_rgb(i):
    x = np.array(cm.tab10(i))[:3]*255
    return tuple(x)

# %%
colors = []

# %%
# One color for each single digit
# creamos los 10 colores, diferenciados para poder identificarlos
# colores cualitativos, qualitative colormaps, separados en varios sectores
# https://matplotlib.org/tutorials/colors/colormaps.html
for i in range(10):
    colors.append(create_rgb(i))

# %%
colors
# Out:
# [(31.0, 119.0, 180.0),
#  (255.0, 127.0, 14.0),
#  (44.0, 160.0, 44.0),
#  (214.0, 39.0, 40.0),
#  (148.0, 103.0, 189.0),
#  (140.0, 86.0, 75.0),
#  (227.0, 119.0, 194.0),
#  (127.0, 127.0, 127.0),
#  (188.0, 189.0, 34.0),
#  (23.0, 190.0, 207.0)]

# %% [markdown]
# ### Setting Up Callback Function

# %%
colors
# Out:
# [(31.0, 119.0, 180.0),
#  (255.0, 127.0, 14.0),
#  (44.0, 160.0, 44.0),
#  (214.0, 39.0, 40.0),
#  (148.0, 103.0, 189.0),
#  (140.0, 86.0, 75.0),
#  (227.0, 119.0, 194.0),
#  (127.0, 127.0, 127.0),
#  (188.0, 189.0, 34.0),
#  (23.0, 190.0, 207.0)]

# %%
# Numbers 0-9
n_markers = 10

# Default settings
current_marker = 1
marks_updated = False #Si los marcadores fueron actualizados

# %%
def mouse_callback(event, x, y, flags, param):
    global marks_updated 

    if event == cv2.EVENT_LBUTTONDOWN:
        
        # TRACKING FOR MARKERS
        # para los marcadores 
        cv2.circle(marker_image, (x, y), 10, (current_marker), -1)
        
        # DISPLAY ON USER IMAGE
        # lo que el usuario ve en la imagen
        cv2.circle(road_copy, (x, y), 10, colors[current_marker], -1)
        marks_updated = True

# %%
cv2.namedWindow('Road Image')
cv2.setMouseCallback('Road Image', mouse_callback)

plt.imshow(marker_image)

while True:
    
    # SHow the 2 windows
    cv2.imshow('WaterShed Segments', segments)
    cv2.imshow('Road Image', road_copy)
        
        
    # Close everything if Esc is pressed
    k = cv2.waitKey(1)

    if k == 27:
        break
        
    # Clear all colors and start over if 'c' is pressed
    elif k == ord('c'):
        road_copy = road.copy()
        marker_image = np.zeros(road.shape[0:2], dtype=np.int32)
        segments = np.zeros(road.shape,dtype=np.uint8)
        
    # If a number 0-9 is chosen index the color
    elif k > 0 and chr(k).isdigit():
        # chr converts to printable digit
        
        current_marker  = int(chr(k))
        
        # CODE TO CHECK INCASE USER IS CARELESS
#         n = int(chr(k))
#         if 1 <= n <= n_markers:
#             current_marker = n
    
    # If we clicked somewhere, call the watershed algorithm on our chosen markers
    # Solo cuando se le da click
    if marks_updated:
        
        # en base a los puntos que definimos (no en lo que ve el usuario sino en los marcadoes)
        # genera el algoritmo la imagen
        marker_image_copy = marker_image.copy()
        cv2.watershed(road, marker_image_copy)
        
        segments = np.zeros(road.shape,dtype=np.uint8)
        
        for color_ind in range(n_markers):
            segments[marker_image_copy == (color_ind)] = colors[color_ind]
        
        marks_updated = False
        
cv2.destroyAllWindows()
